# %%
data_points = [(0.619,0.138),
(0.618,0.136),
(0.618,0.135),
(0.618,0.136),
(0.616,0.136),
(0.616,0.136),
(0.616,0.136),
(0.614,0.137),
(0.613,0.136),
(0.612,0.139),
(0.612,0.135),
(0.611,0.137),
(0.608,0.139),
(0.608,0.133),
(0.606,0.129),
(0.606,0.139),
(0.605,0.140),
(0.605,0.137),
(0.604,0.140),
(0.603,0.134),
(0.600,0.199),
(0.600,0.134),
(0.598,0.139),
(0.598,0.141),
(0.597,0.131),
(0.597,0.137),
(0.596,0.136),
(0.596,0.137),
(0.596,0.138),
(0.596,0.135),
(0.594,0.135),
(0.593,0.137),
(0.592,0.135),
(0.592,0.137),
(0.592,0.137),
(0.592,0.137),
(0.591,0.137),
(0.591,0.137),
(0.591,0.137),
(0.591,0.137),
(0.591,0.138),
(0.590,0.137),
(0.590,0.138),
(0.587,0.139),
(0.587,0.138),
(0.587,0.140),
(0.586,0.136),
(0.585,0.136),
(0.584,0.136),
(0.583,0.137),
(0.583,0.134),
(0.581,0.136),
(0.581,0.137),
(0.580,0.136),
(0.580,0.136),
(0.579,0.136),
(0.577,0.138),
(0.576,0.137),
(0.574,0.135),
(0.574,0.140),
(0.573,0.140),
(0.573,0.135),
(0.573,0.136),
(0.573,0.138),
(0.571,0.135),
(0.571,0.139),
(0.568,0.123),
(0.568,0.136),
(0.567,0.137),
(0.565,0.135),
(0.565,0.292),
(0.565,0.138),
(0.562,0.140),
(0.562,0.136),
(0.561,0.136),
(0.560,0.139),
(0.560,0.139),
(0.558,0.137),
(0.555,0.138),
(0.554,0.136),
(0.552,0.139),
(0.552,0.138),
(0.550,0.138),
(0.549,0.136),
(0.548,0.137),
(0.548,0.136),
(0.547,0.136),
(0.546,0.518),
(0.546,0.135),
(0.545,0.136),
(0.545,0.136),
(0.542,0.139),
(0.541,0.139),
(0.540,0.137),
(0.539,0.137),
(0.539,0.137),
(0.539,0.136),
(0.539,0.137),
(0.538,0.138),
(0.538,0.225),
(0.538,0.163),
(0.538,0.139),
(0.537,0.137),
(0.537,0.137),
(0.536,0.137),
(0.534,0.137),
(0.533,0.136),
(0.533,0.138),
(0.533,0.140),
(0.532,0.138),
(0.532,0.136),
(0.532,0.137),
(0.531,0.269),
(0.531,0.135),
(0.530,0.137),
(0.530,0.140),
(0.529,0.208),
(0.529,0.136),
(0.528,0.136),
(0.527,0.138)]

# %%
import matplotlib.pyplot as plt
# Extracting 'auroc' and 'rmse' values from results
auroc_values, rmse_values = zip(*data_points)
# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(auroc_values, rmse_values, c='blue', alpha=0.5)

# Adding labels and title
plt.xlabel('AUROC')
plt.ylabel('RMSE')
plt.ylim((min(rmse_values)-.005,.145))
# plt.ylim((min(rmse_values),max(rmse_values)))
plt.title(f'Scatter Plot of AUROC vs RMSE ({min(rmse_values):.3f})')

# Display the plot
plt.show()
